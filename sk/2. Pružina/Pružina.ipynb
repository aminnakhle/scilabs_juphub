# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# **Kinematika & harmonický pohyb**

# %% [markdown]
# Aký je vzťah medzi polohou (pozíciou objektu v čase), rýchlosťou a zrýchlením? O koľko viac sa natiahne pružina, ak na ňu zavesíme 2x ťažšie závažie? Čo je to lineárny harmonický oscilátor? A ako to, že pomocou neho možno modelovať množstvo javov a systémov od závažia na pružinke cez bóje na morskej hladine až po kvantové častice?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
df = pd.read_excel(r"hrany.xlsx", index_col=0 )
#format = '%Y-%m-%d %H:%M:%S.%f'

t_start = datetime.strptime( df.index[0], format ).timestamp()
time = [ datetime.strptime( x, format ).timestamp() - t_start for x in df.index ]
# Out:
# [0.0, 0.059999942779541016, 0.09099984169006348, 0.21000003814697266, 0.24099993705749512, 0.3299999237060547, 0.42100000381469727, 0.4500000476837158, 0.6299998760223389, 0.6599998474121094, 0.6909999847412109, 0.809999942779541, 0.869999885559082, 0.8999998569488525, 1.0199999809265137, 1.0509998798370361, 1.1410000324249268, 1.2300000190734863, 1.2599999904632568, 1.4099998474121094, 1.4709999561309814, 1.500999927520752, 1.619999885559082, 1.6510000228881836, 1.7400000095367432, 1.8309998512268066, 1.8610000610351562, 2.0399999618530273, 2.07099986076355, 2.1009998321533203, 2.2200000286102295, 2.2809998989105225, 2.310999870300293, 2.429999828338623, 2.4600000381469727, 2.6399998664855957, 2.669999837875366, 2.819999933242798, 2.88100004196167, 2.9110000133514404, 3.0299999713897705, 3.059999942779541, 3.1510000228881836, 3.240999937057495, 3.2699999809265137, 3.450000047683716, 3.4800000190734863, 3.510999917984009, 3.629999876022339, 3.690999984741211, 3.7200000286102295, 3.83
# ...
